# %%
import numpy as np
from PIL import Image
from torchvision import transforms

def get_midas_transform():
    transform = transforms.Compose([
    transforms.Resize((192, 256)),  
    transforms.ToTensor()
    ])
    return transform

# %%
p = '/home/yasin/Downloads/forpaper/rgb_00010.png'

# %%
i = Image.open(p)

# %%
t = get_midas_transform()

# %%
inp = t(i)

# %%
inp.min()
# Out:
# tensor(0.)

# %%
import matplotlib.pyplot as plt
plt.imshow(inp.permute(1,2,0))

# %%
n = np.array(i)

# %%
inp2 = t(i)

# %%
inp.shape
# Out:
# torch.Size([3, 192, 256])

# %%
img = np.random.random((10,192,256,3))
input_ndim = (1,192,256,3)
output_ndim = (192,256)
batchSize = input_ndim[0]
n_of_images = len(img)
count = 0
write_index = 0
while count < n_of_images:
    if (count+batchSize<=n_of_images):
        runSize = batchSize
    else:
        runSize=n_of_images-count

    '''prepare batch input/output '''
    outputData = []
    inputData = []
    inputData = [np.empty(input_ndim, dtype=np.float32, order="C")]
    outputData = [np.empty(output_ndim, dtype=np.float32, order="C")]

    '''init input image to input buffer '''
    for j in range(runSize):
        imageRun = inputData[0]
        imageRun[j, ...] = img[(count + j) % n_of_images].reshape(input_ndim[1:])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 23
#      21 for j in range(runSize):
#      22     imageRun = inputData[0]
# ---> 23     imageRun[j, ...] = img[(count + j) % n_of_images].reshape(input_ndim[1:])
#
# KeyboardInterrupt:

# %%
img[(count + j) % n_of_images].reshape(input_ndim[1:]).shape
# Out:
# (192, 256, 3)

# %%
imageRun.shape
# Out:
# (1, 192, 256, 3)

# %%
imageRun[j, ...].shape
# Out:
# (192, 256, 3)
