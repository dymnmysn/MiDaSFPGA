# %%
import numpy as np
ar = np.load(r'E:\projeler\fakequant\MiDaSFPGA\data\depth_00065.npy')

# %%
ar.shape
# Out:
# (480, 640)

# %%
ar.dtype
# Out:
# dtype('float16')

# %%
ar.min()
# Out:
# np.float16(0.0)

# %%
ar.max()
# Out:
# np.float16(6.957)
